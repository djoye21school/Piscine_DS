# %%
import requests
import pandas as pd
import json
r = requests.get("https://api.hh.ru/vacancies?text=data scientist")
df = pd.DataFrame(r.json())

# %%
df.to_json('hh.json')

# %%
parsed = json.loads('hh.json')
json.dumps(parsed, indent=4)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-10-925d7bc584b0> in <module>
# ----> 1 parsed = json.loads('hh.json')
#       2 json.dumps(parsed, indent=4)
#
# ~\anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~\anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~\anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
# ...

# %%
pd.DataFrame(r.json()['items'])
# Out:
#           id  premium                                               name  \
# 0   42813933    False               Data Scientist (компьютерное зрение)
# 1   42277725    False  Data Scientist (аналитик данных в области упра...
# 2   42844649    False                                     Data Scientist
# 3   42891788    False           Младший аналитик / Data Scientist Junior
# 4   42683816    False                                     Data Scientist
# 5   41827452     True                   Аналитик данных (Data scientist)
# 6   42782002    False                          Data Scientist / Аналитик
# 7   42832748    False                                     Data Scientist
# 8   39912622    False           Data Scientist / Quantitative Researcher
# 9   42880923    False                                     Data scientist
# 10  42783985    False                              Junior Data Scientist
# 11  42878760    False                     Python Developer / ML Engineer
# ...

# %%
pd.DataFrame(r.json()['items'])['url']
# Out:
# 0     https://api.hh.ru/vacancies/42813933?host=hh.ru
# 1     https://api.hh.ru/vacancies/42277725?host=hh.ru
# 2     https://api.hh.ru/vacancies/42844649?host=hh.ru
# 3     https://api.hh.ru/vacancies/42891788?host=hh.ru
# 4     https://api.hh.ru/vacancies/42683816?host=hh.ru
# 5     https://api.hh.ru/vacancies/41827452?host=hh.ru
# 6     https://api.hh.ru/vacancies/42782002?host=hh.ru
# 7     https://api.hh.ru/vacancies/42832748?host=hh.ru
# 8     https://api.hh.ru/vacancies/39912622?host=hh.ru
# 9     https://api.hh.ru/vacancies/42880923?host=hh.ru
# 10    https://api.hh.ru/vacancies/42783985?host=hh.ru
# 11    https://api.hh.ru/vacancies/42878760?host=hh.ru
# 12    https://api.hh.ru/vacancies/42908865?host=hh.ru
# 13    https://api.hh.ru/vacancies/42554963?host=hh.ru
# 14    https://api.hh.ru/vacancies/42588736?host=hh.ru
# 15    https://api.hh.ru/vacancies/42858638?host=hh.ru
# 16    https://api.hh.ru/vacancies/42766574?host=hh.ru
# ...

# %%
pd.DataFrame(r.json()['items']).columns
# Out:
# Index(['id', 'premium', 'name', 'department', 'has_test',
#        'response_letter_required', 'area', 'salary', 'type', 'address',
#        'response_url', 'sort_point_distance', 'published_at', 'created_at',
#        'archived', 'apply_alternate_url', 'insider_interview', 'url',
#        'alternate_url', 'relations', 'employer', 'snippet', 'contacts',
#        'schedule', 'working_days', 'working_time_intervals',
#        'working_time_modes', 'accept_temporary'],
#       dtype='object')
